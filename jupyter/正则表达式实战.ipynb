# %%
html='''<ul class="list-col list-col5 list-express slide-item">
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27589516/?icn=index-editionrecommend" title="长长的路 我们慢慢走">
                <img src="https://img3.doubanio.com/lpic/s29618085.jpg" class="" width="115px" height="172px" alt="长长的路 我们慢慢走">
              </a>
            </div>
                <div class="intervenor-info">
                    <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class="jd-icon" width="16" height="16"> 
                    <span>推荐</span>
                </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27589516/?icn=index-editionrecommend" title="长长的路 我们慢慢走">长长的路 我们慢慢走</a>
              </div>
              <div class="author">
                余光中
              </div>
              <div class="more-meta">
                <h4 class="title">
                  长长的路 我们慢慢走
                </h4>
                <p>
                  <span class="author">
                    余光中
                  </span>
                  /
                  <span class="year">
                    2017-12-1
                  </span>
                  /
                  <span class="publisher">
                    光明日报出版社
                  </span>
                </p>
                <p class="abstract">
                  
                  本书精选余光中先生散文36篇，包括游记见闻、感情经历、生活智慧、人情世故、文化随感这五部分内容。
在这本书里余光中先生以人生过来人的姿态，为每一个读者提供生命的启示和前行的力量。
物质支撑人的生活，而信念支撑人的灵魂。人生这趟旅途，“去向远方”是每个人生命中最浪漫的冲动，也是每个人对抗孤独与现实的力量之源。
我们的生命，短暂却又漫长，短暂的是外...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27157991/?icn=index-editionrecommend" title="小仓百人一首">
                <img src="https://img3.doubanio.com/lpic/s29581063.jpg" class="" width="115px" height="172px" alt="小仓百人一首">
              </a>
            </div>
                <div class="intervenor-info">
                    <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class="jd-icon" width="16" height="16"> 
                    <span>推荐</span>
                </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27157991/?icn=index-editionrecommend" title="小仓百人一首">小仓百人一首</a>
              </div>
              <div class="author">
                [日] 藤原定家 编著
              </div>
              <div class="more-meta">
                <h4 class="title">
                  小仓百人一首
                </h4>
                <p>
                  <span class="author">
                    [日] 藤原定家 编著
                  </span>
                  /
                  <span class="year">
                    2017-11
                  </span>
                  /
                  <span class="publisher">
                    新星出版社
                  </span>
                </p>
                <p class="abstract">
                  
                  藤原定家从《古今和歌集》《新古今和歌集》等《敕撰和歌集》中，依年代先后挑选出100位介于天智天皇到顺德天皇间的杰出歌人及其一首作品，结集成《百人一首》，又称《小仓百人一首》。合计有男性歌人79人（包括僧侣13人）及女性21人。江户时代以后，由于浮世绘盛行带动版画技术精进，《百人一首》以和歌搭配画作的形态普及于庶民阶层。本书正是由100幅珍品浮世绘画...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27169888/?icn=index-editionrecommend" title="不会讲故事，怎么带团队">
                <img src="https://img3.doubanio.com/lpic/s29577611.jpg" class="" width="115px" height="172px" alt="不会讲故事，怎么带团队">
              </a>
            </div>
                <div class="intervenor-info">
                    <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class="jd-icon" width="16" height="16"> 
                    <span>推荐</span>
                </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27169888/?icn=index-editionrecommend" title="不会讲故事，怎么带团队">不会讲故事，怎么带团队</a>
              </div>
              <div class="author">
                [澳] 肖恩·卡拉汉
              </div>
              <div class="more-meta">
                <h4 class="title">
                  不会讲故事，怎么带团队
                </h4>
                <p>
                  <span class="author">
                    [澳] 肖恩·卡拉汉
                  </span>
                  /
                  <span class="year">
                    2017-12
                  </span>
                  /
                  <span class="publisher">
                    中国友谊出版公司
                  </span>
                </p>
                <p class="abstract">
                  
                  斩获美国著名的商业图书大奖AXIOM年度商业图书金奖，全球著名的商业故事咨询公司Anecdote创始人肖恩•卡拉汉首部国内引进作品：《不会讲故事怎么带团队》，用13年培训世界500强公司讲故事经验，以12类故事模板、32个真实故事，全面揭秘世界500强公司讲故事之法，故事思维集大成者用4步讲出打动人心、激发效率好故事的实战手册。
【本书看点】
	荣获商业图书大奖（...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27607246/?icn=index-editionrecommend" title="一年里要做的12件事">
                <img src="https://img3.doubanio.com/lpic/s29642840.jpg" class="" width="115px" height="172px" alt="一年里要做的12件事">
              </a>
            </div>
                <div class="intervenor-info">
                    <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class="jd-icon" width="16" height="16"> 
                    <span>推荐</span>
                </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27607246/?icn=index-editionrecommend" title="一年里要做的12件事">一年里要做的12件事</a>
              </div>
              <div class="author">
                熊琼
              </div>
              <div class="more-meta">
                <h4 class="title">
                  一年里要做的12件事
                </h4>
                <p>
                  <span class="author">
                    熊琼
                  </span>
                  /
                  <span class="year">
                    2017-11-1
                  </span>
                  /
                  <span class="publisher">
                    重庆大学出版社
                  </span>
                </p>
                <p class="abstract">
                  
                  或许你不会见到比这更奇特，更复杂，更富有仪式感的“书”了吧。
这本名叫《一年里要做的12件事》的封面、封底由纯木制成，内含内文无法正常打开的心灵指引手册和一本名为penguin week calendar的周历记事本以及2018年日历。而在这本书的设计师特别版里，更是囊括了“素木生活”铅笔手绘图集，实木画框，以及环保木盒。
本书编者熊琼是国内顶级书籍设计师。其设计作...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27199630/?icn=index-editionrecommend" title="寻茶问道">
                <img src="https://img3.doubanio.com/lpic/s29652135.jpg" class="" width="115px" height="172px" alt="寻茶问道">
              </a>
            </div>
                <div class="intervenor-info">
                    <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class="jd-icon" width="16" height="16"> 
                    <span>推荐</span>
                </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27199630/?icn=index-editionrecommend" title="寻茶问道">寻茶问道</a>
              </div>
              <div class="author">
                白子一
              </div>
              <div class="more-meta">
                <h4 class="title">
                  寻茶问道
                </h4>
                <p>
                  <span class="author">
                    白子一
                  </span>
                  /
                  <span class="year">
                    2017-12
                  </span>
                  /
                  <span class="publisher">
                    九州出版社
                  </span>
                </p>
                <p class="abstract">
                  
                  本书由知名茶人静清和老师作序推荐；作者多年从事茶艺培训工作，经验丰富；作者深入茶区、茶山，与一线茶农、茶人进行接触，对茶的了解更加可靠；本书收录作者百余幅精美摄影作品，图文并茂，版式精美。
世界上本没有路，走的人多了，便成了路。漫漫茶路也是这样，从荒山、从莽野、从湖泊、从绿洲，一路披荆斩棘，蜿蜒崎岖，能有志于茶，敢于踽踽独行，以苦为乐的，就...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27050196/?icn=index-latestbook-subject" title="明">
                <img src="https://img3.doubanio.com/lpic/s29601592.jpg" class="" width="115px" height="172px" alt="明">
              </a>
            </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27050196/?icn=index-latestbook-subject" title="明">明</a>
              </div>
              <div class="author">
                [新西兰] 埃莉诺·卡顿
              </div>
              <div class="more-meta">
                <h4 class="title">
                  明
                </h4>
                <p>
                  <span class="author">
                    [新西兰] 埃莉诺·卡顿
                  </span>
                  /
                  <span class="year">
                    2018-1
                  </span>
                  /
                  <span class="publisher">
                    译林出版社/凤凰壹力
                  </span>
                </p>
                <p class="abstract">
                  
                  本书的故事背景设置于1866年的新西兰淘金热时期，十二名男子在一间酒店开会，去往新西兰淘金的沃尔特·穆迪下船后走进了这家名为皇冠的旅店,结果误闯入一个奇怪的“聚会”，引发一连串看似巧合的事件和调查。原来，两周前这里发生了一系列神秘的事件：采矿人埃默里突然失踪；吸毒成瘾的妓女安娜企图自杀；醉汉克罗斯比的小屋里发现了巨额的财富……这些混乱的事件让...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27594833/?icn=index-latestbook-subject" title="我们生活的故事">
                <img src="https://img1.doubanio.com/lpic/s29625569.jpg" class="" width="115px" height="172px" alt="我们生活的故事">
              </a>
            </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27594833/?icn=index-latestbook-subject" title="我们生活的故事">我们生活的故事</a>
              </div>
              <div class="author">
                [美] 马克·斯特兰德
              </div>
              <div class="more-meta">
                <h4 class="title">
                  我们生活的故事
                </h4>
                <p>
                  <span class="author">
                    [美] 马克·斯特兰德
                  </span>
                  /
                  <span class="year">
                    2018-1
                  </span>
                  /
                  <span class="publisher">
                    浦睿文化·湖南文艺出版社
                  </span>
                </p>
                <p class="abstract">
                  
                  马克·斯特兰德，影响一代美国诗人的桂冠诗人，一生获奖无数，其诗歌被翻译成30多种语言。他被称为“深沉的异化哀悼者”，他机敏、克制，以深刻的智慧讲述我们被遮蔽的生活故事：有关现代生活的孤独、被异化、焦虑，以及面对广阔世界时的无力感。
《我们生活的故事》完整收录了斯特兰德前半生6部重要的诗集，辑录的108首佳作包括广为流传的《食诗》《新诗歌手册》《...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27171658/?icn=index-latestbook-subject" title="她一生的秘密">
                <img src="https://img3.doubanio.com/lpic/s29602814.jpg" class="" width="115px" height="172px" alt="她一生的秘密">
              </a>
            </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27171658/?icn=index-latestbook-subject" title="她一生的秘密">她一生的秘密</a>
              </div>
              <div class="author">
                [澳] 凯特·莫顿
              </div>
              <div class="more-meta">
                <h4 class="title">
                  她一生的秘密
                </h4>
                <p>
                  <span class="author">
                    [澳] 凯特·莫顿
                  </span>
                  /
                  <span class="year">
                    2017-12-1
                  </span>
                  /
                  <span class="publisher">
                    文汇出版社
                  </span>
                </p>
                <p class="abstract">
                  
                  ※一个世纪有多少秘密，一个女人就有多少秘密※
·
创造南半球销量奇迹的女作家
横扫北半球多国畅销小说榜单
·
42个国家和地区，34种语言版本，作品全球总销量突破1000万册！
★荣获澳大利亚书业ABIA“年度小说”
★昆士兰读者票选“年度小说”
★西班牙读者票选“年度 外国小说”
★英国《星期日泰晤士报》最佳畅销书
★美国《纽约时报》十佳畅销书
★以无人能及的票数获选“...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27176957/?icn=index-latestbook-subject" title="战争、枪炮与选票">
                <img src="https://img1.doubanio.com/lpic/s29636157.jpg" class="" width="115px" height="172px" alt="战争、枪炮与选票">
              </a>
            </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27176957/?icn=index-latestbook-subject" title="战争、枪炮与选票">战争、枪炮与选票</a>
              </div>
              <div class="author">
                [英] 保罗·科利尔
              </div>
              <div class="more-meta">
                <h4 class="title">
                  战争、枪炮与选票
                </h4>
                <p>
                  <span class="author">
                    [英] 保罗·科利尔
                  </span>
                  /
                  <span class="year">
                    2018-1
                  </span>
                  /
                  <span class="publisher">
                    理想国 | 南京大学出版社
                  </span>
                </p>
                <p class="abstract">
                  
                  为什么在极端贫穷的社会里，政治暴力如此普遍？要如何才能遏制它？在全球最贫困10亿人的地区，如非洲的埃塞俄比亚、乌干达、肯尼亚等国，其部落传统造成人民无法形成国家认同，选举也无法扼止部落间的战争。这些地区的国家结构性缺陷，也导致经济无法正常发展，人民只能仰赖国际援助基本的生活必需品。然而贫困的小国政府对主权的激烈捍卫，再加上领导人的软弱和冷...
                </p>
              </div>
            </div>
          </li>
          
  
          <li class="">
            <div class="cover">
              <a href="https://book.douban.com/subject/27252756/?icn=index-latestbook-subject" title="不吃鸡蛋的人">
                <img src="https://img1.doubanio.com/lpic/s29617777.jpg" class="" width="115px" height="172px" alt="不吃鸡蛋的人">
              </a>
            </div>
            <div class="info">
              <div class="title">
                <a class="" href="https://book.douban.com/subject/27252756/?icn=index-latestbook-subject" title="不吃鸡蛋的人">不吃鸡蛋的人</a>
              </div>
              <div class="author">
                钱佳楠
              </div>
              <div class="more-meta">
                <h4 class="title">
                  不吃鸡蛋的人
                </h4>
                <p>
                  <span class="author">
                    钱佳楠
                  </span>
                  /
                  <span class="year">
                    2018-1
                  </span>
                  /
                  <span class="publisher">
                    中信出版集团
                  </span>
                </p>
                <p class="abstract">
                  
                  ******
2018年度青年女性之书《不吃鸡蛋的人》，讲述与原生家庭的关系、说不出口的爱情，以及青年人的自我成长。
******
女孩周允生长在简朴的工人家庭，母亲精明好强，父亲温和懦弱。从童年起，她就被视作母亲改变命运的“稻草”，一直乖巧懂事地成为着父母眼中有出息的孩子——考上重点中学、重点大学，甚至为了省一笔住校费用，假装自己对鸡蛋过敏。直到遇见特立独行...
                </p>
              </div>
            </div>
          </li>
    </ul>
'''
import requests
import re

results=re.findall('<li.*?cover.*?href="(.*?)".*?title="(.*?)".*?more-meta.*?author">(.*?)</span>.*?year">(.*?)</span>.*?</li>',html,re.S)
print(results)
for result in results:
    url,name,author,date = result
    print(url,name,author,date)
# Out:
# [('https://book.douban.com/subject/27589516/?icn=index-editionrecommend', '长长的路 我们慢慢走', '\n                    余光中\n                  ', '\n                    2017-12-1\n                  '), ('https://book.douban.com/subject/27157991/?icn=index-editionrecommend', '小仓百人一首', '\n                    [日] 藤原定家 编著\n                  ', '\n                    2017-11\n                  '), ('https://book.douban.com/subject/27169888/?icn=index-editionrecommend', '不会讲故事，怎么带团队', '\n                    [澳] 肖恩·卡拉汉\n                  ', '\n                    2017-12\n                  '), ('https://book.douban.com/subject/27607246/?icn=index-editionrecommend', '一年里要做的12件事', '\n                    熊琼\n                  ', '\n                    2017-11-1\n                  '), ('https://book.douban.com/subject/27199630/?icn=index-editionrecommend', '寻茶问道', '\n                    白子一\n                  ', '\n                    2017-12\n                  '), ('https://book.douban.com/subject/2705
# ...

# %%
import requests
import re

content= requests.get('https://book.douban.com/').text
pattern = re.compile('<li.*?cover.*?href="(.*?)".*?title="(.*?)".*?more-meta.*?author">(.*?)</span>.*?year">(.*?)</span>.*?</li>',re.S)
results=re.findall(pattern,content)
print(results)
for result in results:
    url,name,author,date = result
    author=re.sub('\s','',author)
    date=re.sub('\s','',date)
    print(url,name,author,date)
